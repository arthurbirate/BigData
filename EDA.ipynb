# %%
# !pip install opencv-python
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

# %%
# Set your dataset path
dataset_path = './SeaBirds/ducks/'


# Function to load and visualize random images from the dataset
def visualize_random_images(data_path, num_images=5):
    plt.figure(figsize=(15, 5))
    plt.suptitle('Random Sample Images from the Dataset')

    # List all image files in the dataset path
    image_files = [item for item in os.listdir(data_path) if os.path.isfile(os.path.join(data_path, item))]

    for i in range(num_images):
        # Choose a random image file
        img_name = np.random.choice(image_files)
        img_path = os.path.join(data_path, img_name)

        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        plt.subplot(1, num_images, i + 1)
        plt.imshow(img)
        plt.title(f'Image: {img_name}')

    plt.show()

visualize_random_images(dataset_path)
